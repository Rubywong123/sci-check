# %%
import json
import pandas as pd

# %%
# parse "evidence" column
import jsonlines


df = pd.DataFrame(columns = ['id', 'claim', 'evidence'])
with open('data/claims.jsonl', 'r', encoding = 'utf-8') as f:
    for item in jsonlines.Reader(f):
        df.loc[len(df)] = item
    
df = df.set_index('id')

# %%
# 279 claims in total
df[df['evidence'] == {}]
# 73 claims without evidence

df['num_evidence'] = df['evidence'].map(lambda x: len(x.keys()))
df[df['num_evidence'] == 1]
# 125 claims with 1 evidence

df[df['num_evidence'] == 2].count()
# 36 claims with 2 evidences

df[df['num_evidence'] == 3].count()
# 12 claims with 3 evidences

df[df['num_evidence'] == 4].count()
# 11 claims with 4 evidences

df[df['num_evidence'] == 5].count()
# 8 claims with 5 evidences

df[df['num_evidence'] == 6].count()
# 5 claims with 6 evidences

df[df['num_evidence'] > 6]
# 9 claims with more than 6 evidences
# Out:
#                                                   claim  \
# id
# 170   Bariatric surgery reduces resolution of diabetes.
# 207       CHEK2 has a significant role in breast cancer
# 215     CRY proteins mediate light signal transduction.
# 451   Gene expression can be highly variable across ...
# 534   Hypertension can be accurately diagnosed with ...
# 599   Incidence rates of cervical cancer have increa...
# 794   Mitochondria are uninvolved in processes relat...
# 872   Obesity is determined in part by genetic factors.
# 1296  There is no relation between lupus erythematos...
#
#                                                evidence  num_evidence
# id
# 170   {'5824985': {'provenance': 'citation', 'label'...             9
# 207   {'13519661': {'provenance': 'citation', 'label...             9
# 215   {'5035851': {'provenance': 'citation', 'label'...             7
# 451   {'12804937': {'provenance': 'citation', 'label...            11
# 534   {'25515907': {'provenance': 'citation', 'label...             8
# 599   {'12779444': {'provenance': 'citation', 'label...             9
# 794   {'8551160': {'provenance': 'citation', 'label'...            20
# 872   {'1180972': {'provenance': 'citation', 'label'...            24
# 1296  {'27466734': {'provenance': 'citation', 'label...            16

# %%
flatten_df = pd.DataFrame(columns= ['claim', 'doc_id', 'provenance', 'label', 'sentences', 'model_ranks'])

# NEI not included
for row in df.index:
    for key in df.loc[row]['evidence']:
        flatten_df.loc[len(flatten_df)] = {'claim': df.loc[row]['claim'], 'doc_id': key, 'provenance': df.loc[row]['evidence'][key]['provenance'], 
        'label': df.loc[row]['evidence'][key]['label'], 'sentences': df.loc[row]['evidence'][key]['sentences'], 'model_ranks': df.loc[row]['evidence'][key]['model_ranks']}

flatten_df
# 460 ECAPs
# Out:
#                                                  claim    doc_id provenance  \
# 0    10-20% of people with severe mental disorder r...   6490571   citation
# 1    A breast cancer patient's capacity to metaboli...  24341590   citation
# 2    A breast cancer patient's capacity to metaboli...   8553718    pooling
# 3    A breast cancer patient's capacity to metaboli...  24313685    pooling
# 4    A breast cancer patient's capacity to metaboli...  30328289    pooling
# ..                                                 ...       ...        ...
# 455  c-MYC is important for maintaining pluripotent...   2002182    pooling
# 456  c-MYC is important for maintaining pluripotent...  21271817    pooling
# 457  c-MYC is important for maintaining pluripotent...  27394882    pooling
# 458  c-MYC is important for maintaining pluripotent...  11900693    pooling
# 459  mTORC2 inhibits xCT antiporter through phospho...  23895668   citation
#
#           label         sentences  \
# 0    CONTRADICT               [7]
# 1    CONTRADICT  [10, 11, 12, 13]
# 2    CONTRADICT               [2]
# 3    CONTRADICT               [3]
# 4    CONTRADICT               [4]
# ..          ...               ...
# 455     SUPPORT                []
# 456     SUPPORT                []
# 457     SUPPORT                []
# 458     SUPPORT                []
# 459     SUPPORT               [2]
#
#                                            model_ranks
# 0                                                 None
# 1                                                 None
# 2    {'multivers_10': 1020, 'multivers_20': 3474, '...
# 3    {'multivers_10': 3764, 'multivers_20': 6319, '...
# 4    {'multivers_10': 10499, 'multivers_20': 5079, ...
# ..                                                 ...
# 455  {'multivers_10': 838, 'multivers_20': 246, 'pa...
# 456  {'multivers_10': 1219, 'multivers_20': 224, 'p...
# 457  {'multivers_10': 680, 'multivers_20': 231, 'pa...
# 458  {'multivers_10': 656, 'multivers_20': 241, 'pa...
# 459                                               None
#
# [460 rows x 6 columns]

# %%
# 209 ECAPs from SciFact-Orig, 251 from pooling S2ORC
flatten_df[flatten_df['provenance'] == 'citation']
# Out:
#                                                  claim    doc_id provenance  \
# 0    10-20% of people with severe mental disorder r...   6490571   citation
# 1    A breast cancer patient's capacity to metaboli...  24341590   citation
# 6    A country's Vaccine Alliance (GAVI) eligibilit...  12428497   citation
# 7    A deficiency of folate decreases blood levels ...  11705328   citation
# 11   APOE4 expression in iPSC-derived neurons resul...   4709641   citation
# ..                                                 ...       ...        ...
# 446  Vitamin D deficiency has no effect on the term...   2425364   citation
# 448  Whole brain radiotherapy reduces the occurrenc...   3944632   citation
# 453  c-MYC is important for maintaining pluripotent...  22843616   citation
# 454  c-MYC is important for maintaining pluripotent...  25300426   citation
# 459  mTORC2 inhibits xCT antiporter through phospho...  23895668   citation
#
#           label         sentences model_ranks
# 0    CONTRADICT               [7]        None
# 1    CONTRADICT  [10, 11, 12, 13]        None
# 6       SUPPORT               [8]        None
# 7    CONTRADICT               [4]        None
# 11      SUPPORT               [1]        None
# ..          ...               ...         ...
# 446  CONTRADICT   [9, 10, 11, 12]        None
# 448     SUPPORT           [6, 10]        None
# 453     SUPPORT               [4]        None
# 454     SUPPORT               [4]        None
# 459     SUPPORT               [2]        None
#
# [209 rows x 6 columns]

# %%
pooling_df = flatten_df[flatten_df['provenance'] == 'pooling']

pooling_df['multivers_10'] = pooling_df['model_ranks'].map(lambda x: x['multivers_10'] if 'multivers_10' in x else None)
pooling_df['multivers_20'] = pooling_df['model_ranks'].map(lambda x: x['multivers_20'] if 'multivers_20' in x else None)
pooling_df['paragraph_joint'] = pooling_df['model_ranks'].map(lambda x: x['paragraph_joint'] if 'paragraph_joint' in x else None)
pooling_df['vert5erini'] = pooling_df['model_ranks'].map(lambda x: x['vert5erini'] if 'vert5erini' in x else None)
pooling_df.fillna(10000)
# Out:
# /var/folders/rn/cg5jcxv170ngv3x_c84r4qm40000gn/T/ipykernel_5123/3536700079.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pooling_df['multivers_10'] = pooling_df['model_ranks'].map(lambda x: x['multivers_10'] if 'multivers_10' in x else None)
# /var/folders/rn/cg5jcxv170ngv3x_c84r4qm40000gn/T/ipykernel_5123/3536700079.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pooling_df['multivers_20'] = pooling_df['model_ranks'].map(lambda x: x['multivers_20'] if 'multivers_20' in x else None)
# /var/folders/rn/cg5jcxv170ngv3x_c84r4qm40000gn/T/ipykernel_5123/3536700079.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pooling_df['paragraph_joint'] = pooling_df['model_ranks'].map(lambda x: x['paragraph_joint'] if 'paragraph_joint' in x else None)
# /var/folders/rn/cg5jcxv170ngv3x_c84r4qm40000gn/T/ipykernel_5123/3536700079.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pooling_df['vert5erini'] = pooling_df['model_ranks'].map(lambda x: x['vert5erini'] if 'vert5erini' in x else None)
#                                                  claim    doc_id provenance  \
# 2    A breast cancer patient's capacity to metaboli...   8553718    pooling
# 3    A breast cancer patient's capacity to metaboli...  24313685    pooling
# 4    A breast cancer patient's capacity to metaboli...  30328289    pooling
# 5    A breast cancer patient's capacity to metaboli...  23838305    pooling
# 8    A deficiency of folate decreases blood levels ...  23526574    pooling
# ..                                                 ...       ...        ...
# 452  Whole brain radiotherapy reduces the occurrenc...   1254092    pooling
# 455  c-MYC is important for maintaining pluripotent...   2002182    pooling
# 456  c-MYC is important for maintaining pluripotent...  21271817    pooling
# 457  c-MYC is important for maintaining pluripotent...  27394882    pooling
# 458  c-MYC is important for maintaining pluripotent...  11900693    pooling
#
#           label sentences                                        model_ranks  \
# 2    CONTRADICT       [2]  {'multivers_10': 1020, 'multivers_20': 3474, '...
# 3    CONTRADICT       [3]  {'multivers_10': 3764, 'multivers_20': 6319, '...
# 4    CONTRADICT       [4]  {'multivers_10': 10499, 'multivers_20': 5079, ...
# 5    CONTRADICT      [13]  {'multivers_10': 767, 'multivers_20': 1410, 'p...
# 8    CONTRADICT       [6]  {'multivers_10': 3494, 'multivers_20': 4704, '...
# ..          ...       ...                                                ...
# 452     SUPPORT    [0, 1]  {'multivers_10': 464, 'multivers_20': 1025, 'p...
# 455     SUPPORT        []  {'multivers_10': 838, 'multivers_20': 246, 'pa...
# 456     SUPPORT        []  {'multivers_10': 1219, 'multivers_20': 224, 'p...
# 457     SUPPORT        []  {'multivers_10': 680, 'multivers_20': 231, 'pa...
# 458     SUPPORT        []  {'multivers_10': 656, 'multivers_20': 241, 'pa...
#
#      multivers_10  multivers_20  paragraph_joint  vert5erini
# 2            1020          3474             1250        84.0
# 3            3764          6319             4631        85.0
# 4           10499          5079             6199       203.0
# 5             767          1410            12229       193.0
# 8            3494          4704              412       108.0
# ..            ...           ...              ...         ...
# 452           464          1025               88       511.0
# 455           838           246             1262     10000.0
# 456          1219           224             9433     10000.0
# 457           680           231             3120     10000.0
# 458           656           241            12603     10000.0
#
# [251 rows x 10 columns]

# %%
# MultiVerS_10 boosts 96 ECAPs
# 46 with rank <= 100
pooling_df[pooling_df['multivers_10'] <= 100].count()

# MultiVerS_20 boosts 92 ECAPs
# 49 with rank <= 100
# pooling_df[pooling_df['multivers_20'] <= 100].count()

# paragraphjoint boosts 106 ECAPs
# 51 with rank <= 100
# pooling_df[pooling_df['paragraph_joint'] <= 100].count()

# vert5erini boosts 86 ECAPs
# 37 with rank <= 100
# pooling_df[pooling_df['vert5erini'] <= 100].count()
# Out:
# claim              46
# doc_id             46
# provenance         46
# label              46
# sentences          46
# model_ranks        46
# multivers_10       46
# multivers_20       46
# paragraph_joint    46
# vert5erini         33
# dtype: int64

# %%
meta_df = pd.DataFrame(columns = ['id', 'source_doc_id', 'source_metadata'])
with open('data/claims_metadata.jsonl', 'r', encoding = 'utf-8') as f:
    for item in jsonlines.Reader(f):
        meta_df.loc[len(meta_df)] = item

meta_df['arxiv_id'] = meta_df['source_metadata'].map(lambda x: x['arxiv_id'])
meta_df['pmc_id'] = meta_df['source_metadata'].map(lambda x: x['pmc_id'])
meta_df['pubmed_id'] = meta_df['source_metadata'].map(lambda x: x['pubmed_id'])
meta_df['venue'] = meta_df['source_metadata'].map(lambda x: x['venue'])
meta_df['journal'] = meta_df['source_metadata'].map(lambda x: x['journal'])

# None has arxiv id --> None published on Arxiv?
# no preprint included --> more rigorous?
meta_df[~meta_df['arxiv_id'].isnull()]

# #  documents published on PubMed
# meta_df[meta_df['pubmed_id'].isnull()].count()

# #  documents published on PMC
# meta_df[meta_df['pmc_id'].isnull()].count()
# Out:
# Empty DataFrame
# Columns: [id, source_doc_id, source_metadata, arxiv_id, pmc_id, pubmed_id, venue, journal]
# Index: []

# %%
grouped_df = (meta_df.groupby('source_doc_id').count())

# reused documents (probably used to support/refute conflict claims)
len(grouped_df[grouped_df['id'] > 1])
# Out:
# 44

# %%
df.to_csv("claims.csv", na_rep = 'NA')
